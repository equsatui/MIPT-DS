# %% [markdown]
# # Байесовская статистика
# ## Задание B.1
#
#
# **Правила:**
#
# * Дедлайны см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_ds24_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. **Работы, присланные иным способом, не принимаются.**
# * Дедлайны см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно **ноутбук в формате `ipynb`**.
# * Следите за размером файлов. **Бот не может принимать файлы весом более 20 Мб.** Если файл получается больше, заранее разделите его на несколько.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * В каждой задаче не забывайте делать **пояснения и выводы**.
#
# **Правила оформления теоретических задач:**
#
# * Решения необходимо прислать одним из следующих способов:
#   * фотографией в правильной ориентации, где все четко видно, а почерк разборчив,
#     * отправив ее как файл боту вместе с ноутбуком *или*
#     * вставив ее в ноутбук посредством `Edit -> Insert Image` (<font color="red">фото, вставленные ссылкой, не принимаются</font>);
#   * в виде $LaTeX$ в markdown-ячейках.
# * Решения не проверяются, если какое-то требование не выполнено. Особенно внимательно все проверьте в случае выбора второго пункта (вставки фото в ноутбук). <font color="red"><b>Неправильно вставленные фотографии могут не передаться при отправке.</b></font> Для проверки попробуйте переместить `ipynb` в другую папку и открыть его там.
# * В решениях поясняйте, чем вы пользуетесь, хотя бы кратко. Например, если пользуетесь независимостью, то достаточно подписи вида "*X и Y незав.*"
# * Решение, в котором есть только ответ, и отсутствуют вычисления, оценивается в 0 баллов.
#
# ---
#
# **Баллы за задание:**
#
# * Задача 1 — 60 баллов
# * Задача 2 — 20 баллов
# * Задача 3 — 10 баллов
# * Задача 4 &mdash; 10 баллов
# * Задача 5 — 40 баллов
# * Задача 6 — 30 баллов
# * Задача 7 &mdash; 20 баллов

# %%
import numpy as np
import pandas as pd
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats import multitest

import scikit_posthocs as sp

from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
# Bot check

# HW_ID: ds_bs1
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то.

# Status: final
# Перед отправкой в финальном решении удали "not" в строчке выше.
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную.
# Никакие значения в этой ячейке не влияют на факт сдачи работы.

# %% [markdown]
# ---
# ### Задача 1
#
# Пусть $X_1, \ldots, X_n$ — выборка из распределения $\mathsf{P}$. Подберите сопряженное распределение и найдите апостриорное распределение, его математическое ожидание, моду и медиану, где это возможно
#
# a). $\mathsf{P} = Bin(m, \theta)$, причем $m$ известно.
#
# b). $\mathsf{P} = \mathrm{U}(0, \theta)$. Дополнительно посчитайте апостериорный доверительный интервал.
#
# c). $\mathsf{P} = Cat(\theta_1, \ldots, \theta_k)$ &mdash; категориальное распределение.

# %% [markdown]
# **в прикрепленном PDF**

# %% [markdown]
# ---
# ### Задача 2
#
# Пусть $X_1, \ldots, X_n$ — выборка из неизвестного распределения $\mathsf{P} \in \mathcal{P}$, причем семейство $\mathcal{P} = \{ \mathsf{P}_t \,|\, t \in \Theta \}$ принадлежит экспоненциальному классу распределений.
# Докажите, что существует сопряженное к $\mathcal{P}$ семейство $\mathcal{Q}$, которое также принадлежит экспоненциальному классу распределений.

# %% [markdown]
# **в прикрепленном PDF**

# %% [markdown]
# ---
# ### Задача 3
#
# Пусть семейство распределений $\mathcal{Q} = \{\mathsf{Q}_\alpha \,|\, \alpha \in \mathcal{A} \}$ является сопряженным к $\mathcal{P}$, причем если в качестве априорного распределения было взято $\mathsf{Q}_\alpha$, то апостериорным распределением будет $\mathsf{Q}_{f(\alpha)}$ Найдите апостериорное распределение, если распределение выборки лежит в семействе $\mathcal{P}$, а в качестве априорного взято распределение $\mathsf{Q} = \sum\limits_{j=1}^k \pi_j \mathsf{Q}_{\alpha_j}$, где $\sum\limits_{j=1}^k \pi_j = 1$.

# %% [markdown]
# **в прикрепленном PDF**

# %% [markdown]
# __________________
# ### Задача 4
#
# Пусть $\theta$ &mdash; вероятность успеха в схеме испытаний Бернулли. В качестве неинформативного априорного распределения можно использовать равномерное на отрезке $[0, 1]$. Однако, это не самый лучший способ его определения.
#
# Получите неинформативное априорное распределение для $\theta$ по методу Джеффриса.

# %% [markdown]
# **в прикрепленном PDF**

# %% [markdown]
# ---
# ### Задача 5
#
# Рассмотрим схему испытаний Бернулли (т.е. броски монет) с вероятностью успеха $p$.
#
# **1)** Постройте несколько графиков сопряженного распределения для разных параметров и охарактеризуйте, как его значения параметров соотносятся с априорными знаниями о монете.
# Можно рассмотреть следующие случаи.
# * Монета скорее честная. Тогда наиболее вероятны значения $p$ в окрестности $0.5$.
# * Монета скорее нечестная, перевес неизвестен. Тогда наименее вероятны значения $p$ в окрестности $0.5$.
# * Монета скорее нечестная, перевес в сторону герба. Тогда наиболее вероятны значения $p$ в окрестности $1$.
# * Монета скорее честная, либо с небольшим перекосом вправо. Тогда наиболее вероятны значения $p$ в окрестности $\approx 0.6$.
# * Ничего не известно. Тогда все значния равновероятны.
#
# Для каждого случая из перечисленных выше постройте график плотности сопряженного распределения (на одной фигуре).

# %%
beta_params = {
    "Монета скорее честная (a=10, b=10)": (10, 10),
    "Монета скорее нечестная, перевес неизвестен (a=0.5, b=0.5)": (1/2, 1/2),
    "Монета скорее нечестная, перевес в сторону герба (a=15, b=2)": (15, 2),
    "Монета скорее честная, либо с небольшим перекосом вправо (c=7, b=5)": (7, 5),
    "Ничего не известно (a=1, b=1)": (1, 1),
}

p_values = np.linspace(0, 1, 1000)

plt.figure(figsize=(20, 8))
for label, (alpha, beta) in beta_params.items():
    plt.plot(p_values, sps.beta.pdf(p_values, alpha, beta), label=label)

plt.xlabel("p", fontsize=12)
plt.ylabel("Плотность вероятности", fontsize=12)
plt.title("Графики плотности бета-распределений", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Реализуйте функцию, вычисляющую параметры априорного распределения:

# %%
def bern_posterior_params(sample, a, b):
    '''Находит параметры апостериорного распределения 
    
    :param sample: выборка
    :param a: параметр alpha априорного распределения
    :param b: параметр beta априорного распределения
    
    :returns: параметры апостериорного
    '''
    n_1, n_2 = np.sum(sample == 1), np.sum(sample == 0)
    return n_1 + a, n_2 + b

# %% [markdown]
# **2)** Проведите 15 бросков симметричной монеты и рассмотрите случаи различных априорных распределений, заданных в пункте 1). Отметьте также истинное значение рассматриваемого параметра

# %%
sample = np.random.binomial(1, 0.5, 15)

posterior_params = {
    label: bern_posterior_params(sample, alpha, beta)
    for label, (alpha, beta) in beta_params.items()
}

p_values = np.linspace(0, 1, 1000)
plt.figure(figsize=(20, 8))
for label, (post_alpha, post_beta) in posterior_params.items():
    plt.plot(p_values, sps.beta.pdf(p_values, post_alpha, post_beta), label=label)

plt.axvline(0.5, color='black', linestyle='dashed', label="Истинное p=0.5")

plt.xlabel("p", fontsize=12)
plt.ylabel("Плотность вероятности", fontsize=12)
plt.title("Апостериорные распределения после 15 бросков монеты", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **3)** Проведите аналогичный эксперимент для несимметричной монеты. Сравните полученные апостериорные распределения с апостериорными распределениями в симметричном случае

# %%
sample_biased = np.random.binomial(1, 0.2, 15)

posterior_params_biased = {
    label: bern_posterior_params(sample_biased, alpha, beta)
    for label, (alpha, beta) in beta_params.items()
}

p_values = np.linspace(0, 1, 1000)
plt.figure(figsize=(20, 8))
for label, (post_alpha, post_beta) in posterior_params_biased.items():
    plt.plot(p_values, sps.beta.pdf(p_values, post_alpha, post_beta), label=label)

plt.axvline(0.2, color='black', linestyle='dashed', label="Истинное p=0.7")

plt.xlabel("p", fontsize=12)
plt.ylabel("Плотность вероятности", fontsize=12)
plt.title("Апостериорные распределения после 15 бросков несимметричной монеты", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Сделайте вывод о том, как апостериорное распределение зависит от того, насколько совпадают наши априорные представления с реальностью?

# %% [markdown]
# **Вывод:**
#
# Чем ближе априорные представления к реальности, тем лучше апостериорное распределение приближает истинное распределение бросков (в том смысле, например, что мода апостериорного распределения ближе к истинному)
#
# Например, во втором случае лучший результат (ближе к моде) распределения дает априорное представление с неизвестным перевесом, чуть хуже неизвестный перевес, хуже честная монета, хуже перевес в другую сторону - что очень логично
#
# Аналогичные выводы можно сделать и по честной монете - лучше приближает апостериорное с честным априорным, далее неизвестное, и т.д.

# %% [markdown]
# ---
# ### Задача 6
#
# **1)** В схеме испытаний Бернулли из задачи 4 рассмотрим онлайн-подход: наблюдения поступают батчами, в качестве априорного используется предыдущее апостериорное. Сначала реализуйте функцию генерации батчей:

# %%
def get_sample_bern(theta=0.5, batch_size=5):
    '''
    :returns: батч размера <batch_size> из распределения Bern(<theta>)
    '''
    return np.random.binomial(1, theta, batch_size)

# %% [markdown]
# Допишите функцию, имитирующую онлайн подход:

# %%
def bern_posterior_params_in_batch(batch_count, a_prior, b_prior, theta=0.5, batch_size=5):
    '''
    :param batch_count: количество батчей в выборке
    :param a_prior, b_prior: параметры априорного распределения (до получения выборки)
    :param theta: истинный параметр распределения бернулли
    :param batch_size: размер батча. Размер выборки в таком случае <batch_size> * <batch_count>
    
    :returns: набор апостериорных параметров, полученных после каждого нового батча
    '''
    post_params = [(a_prior, b_prior)]
    a_post, b_post = a_prior, b_prior

    for _ in range(batch_count):
        batch = get_sample_bern(theta, batch_size)
        a_post, b_post = bern_posterior_params(batch, a_post, b_post)
        post_params.append((a_post, b_post))

    return np.array(post_params)

# %% [markdown]
# Ниже приведена реализация вспомогательной функции

# %%
def draw_posteriori(grid, distr_class, post_params, xlim=None):
    '''Рисует серию графиков апостериорных плотностей.
    
    :param grid: сетка для построения графика
    :param distr_class: класс распределений из scipy.stats
    :param post_params: параметры апостериорных распределений 
        shape=(размер выборки, кол-во параметров)
    '''
        
    size = post_params.shape[0] - 1
    
    plt.figure(figsize=(20, 8))
    for n in range(size+1):
        plt.plot(grid, 
                 distr_class(post_params[n]).pdf(grid) \
                     if np.isscalar(post_params[n]) \
                     else distr_class(*post_params[n]).pdf(grid), 
                 label='n={}: {}'.format(n, np.round(post_params[n], 3)), 
                 lw=2.5,
                 color=(1-n/size, n/size, 0))
    plt.title('Апостериорное распределение в зависимости от номера батча')
    plt.legend(fontsize=12)
    plt.xlim(xlim)
    plt.show()

# %% [markdown]
# Рассмотрите произвольную монету. Подберите два априорных распределения так, что в одном случае априорные знания должны совпадать с реальностью, а во втором нет. Рассмотрите как изменяется апостериорное распределение в зависимости от получения нового батча.

# %% [markdown]
# Априорное скорее совпадает, сходится быстрее

# %%
theta_real = 0.6
batch_count = 10
batch_size = 5

a_prior, b_prior = 7, 5

posterior_updates = bern_posterior_params_in_batch(batch_count, a_prior, b_prior, theta_real, batch_size)

p_values = np.linspace(0, 1, 1000)
draw_posteriori(p_values, sps.beta, posterior_updates, xlim=(0, 1))

# %% [markdown]
# Априорное не совпадает, сходится долго

# %%
theta_real = 0.6
batch_count = 10
batch_size = 5

a_prior, b_prior = 1, 5

posterior_updates = bern_posterior_params_in_batch(batch_count, a_prior, b_prior, theta_real, batch_size)

p_values = np.linspace(0, 1, 1000)
draw_posteriori(p_values, sps.beta, posterior_updates, xlim=(0, 1))

# %% [markdown]
# С ростом номера патча апостериорное распределение приближается (мода) к истинному знаечению 0.6

# %% [markdown]
# **2)** Проведите аналогичное исследование для выборки из распределения $Exp(\theta)$

# %% [markdown]
# Апостериорное задается через гамма распределение

# %%
def get_sample_exp(theta=1, batch_size=5):
    '''
    :returns: батч размера <batch_size> из распределения Exp(<theta>)
    '''

    return sps.expon.rvs(1 / theta, size=batch_size)


def exp_posterior_params(sample, a_prior, b_prior):
    '''
    :param sample: выборка
    :param a_prior, b_prior: параметры априорного распределения
    
    :returns: набор апостериорных параметров
    '''
    
    return a_prior + np.sum(sample), b_prior + sample.shape[0] + 1

def exp_posterior_params_in_batch(batch_count, a_prior, b_prior, theta=0.5, batch_size=5):
    '''
    :param batch_count: количество батчей в выборке
    :param a_prior, b_prior: параметры априорного распределения (до получения выборки)
    :param theta: истинный параметр распределения бернулли
    :param batch_size: размер батча. Размер выборки в таком случае <batch_size> * <batch_count>
    
    :returns: набор апостериорных параметров, полученных после каждого нового батча
    '''
    post_params = [(a_prior, b_prior)]
    a_post, b_post = a_prior, b_prior

    for _ in range(batch_count):
        batch = get_sample_exp(theta, batch_size)
        a_post, b_post = exp_posterior_params(batch, a_post, b_post)
        post_params.append((a_post, b_post))

    return np.array(post_params)

# %% [markdown]
# Запускаем, при совпадении априорного:

# %%
theta_real = 0.3
batch_count = 10
batch_size = 5

a_prior, b_prior = 1/theta_real * 3, 3 + 1

posterior_updates = exp_posterior_params_in_batch(batch_count, a_prior, b_prior, theta_real, batch_size)

p_values = np.linspace(0, 1, 1000)
draw_posteriori(p_values, lambda a, b: sps.gamma(a=b, scale=1/a), posterior_updates, xlim=(0, 1))

# %% [markdown]
# Теперь если не совпадает

# %%
theta_real = 0.5
batch_count = 10
batch_size = 5

a_prior, b_prior = 1/0.1 * 10, 10

posterior_updates = exp_posterior_params_in_batch(batch_count, a_prior, b_prior, theta_real, batch_size)

p_values = np.linspace(0, 1, 1000)
draw_posteriori(p_values, lambda a, b: sps.gamma(a=b, scale=1/a), posterior_updates, xlim=(0, 1))

# %% [markdown]
# Как видим, сходимость тем лучше, чем ближе априорное распределение к истинному (если сходимость вообще есть)

# %% [markdown]
# ---
# ### Задача 7
#
# Предположим, что выборка из распределения $\mathcal{N}(\theta_1, \theta_2^{-1})$ приходит постепенно по 5 наблюдений за один раз. До получения первой партии из 5 наблюдений отсутствует какая-либо информация о значениях параметров $\theta = (\theta_1, \theta_2)$. После получения очередной партии наблюдений вычисляется апостериорное распределение параметров, используя в качестве априорного распределения предыдущее апостериорное распределение. Промоделируйте и визуализируйте такой эксперимент и опишите, как меняются знания о параметрах в процессе эксперимента.

# %% [markdown]
# $\theta_1$ генерируем нормально, а $\theta_2$ из гамма распределения (нужна положительность), генерируем согласно формулам ниже

# %%
from IPython.display import Image
Image('params.png')

# %% [markdown]
# Обновляем параметры согласно формулам выше

# %%
def update_posterior(batch, mu_prev, n0_prev, alpha_prev, beta_prev):
    n = len(batch)
    x_bar = np.mean(batch)
    sum_sq = np.sum((batch - x_bar)**2)
    
    new_mu0 = (n * x_bar + n0_prev * mu_prev) / (n + n0_prev)
    new_n0 = n + n0_prev

    new_alpha = alpha_prev + n / 2
    new_beta = beta_prev + 0.5 * sum_sq + 0.5 * (n * n0_prev) / (n + n0_prev) * (x_bar - mu_prev)**2
    
    return new_mu0, new_n0, new_alpha, new_beta

# %% [markdown]
# Запуск

# %%
theta1_true = 5
theta2_true = 2
tau_true = 1 / theta2_true

mu0_prior = 0
n0_prior = 0.01
alpha_prior = 0.0001
beta_prior = 0.0001

batch_size = 15
num_batches = 10

posterior_params = []
mu_current, n0_current = mu0_prior, n0_prior
alpha_current, beta_current = alpha_prior, beta_prior
posterior_params.append((mu_current, n0_current, alpha_current, beta_current))

for batch in data_batches:
    mu_current, n0_current, alpha_current, beta_current = update_posterior(
        batch, mu_current, n0_current, alpha_current, beta_current
    )
    posterior_params.append((mu_current, n0_current, alpha_current, beta_current))

mu_post_params = []
tau_post_params = []

for params in posterior_params:
    mu0, n0, alpha, beta = params
    E_tau = alpha / beta
    sigma = 1 / np.sqrt(n0 * E_tau)
    mu_post_params.append((mu0, sigma))
    
    tau_post_params.append((alpha, 0, 1/beta))

mu_post_params = np.array(mu_post_params)
tau_post_params = np.array(tau_post_params)

mu_grid = np.linspace(3, 7, 500)
tau_grid = np.linspace(0.1, 1.5, 500)

draw_posteriori(mu_grid, sps.norm, mu_post_params, xlim=(3, 7))

draw_posteriori(tau_grid, sps.gamma, tau_post_params, xlim=(0.1, 1.5))

# %% [markdown]
# Действительно, есть сходимость к истинным значениям параметров - 5 и 1/2=0.5
